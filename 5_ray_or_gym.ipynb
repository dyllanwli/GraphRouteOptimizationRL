# %%
import gym
from ray.rllib.agents.ppo import PPOTrainer

# %%
import or_gym
from or_gym.utils import create_env
import ray
from ray.rllib import agents
from ray import tune

# %%
from stable_baselines3 import PPO, A2C
from stable_baselines3.common.env_checker import check_env

# %%
import json

# %%
from ray.tune import ExperimentAnalysis
analysis = ExperimentAnalysis("/h/diya.li/ray_results/PPO")
# Out:
# 2022-04-03 18:58:23,003	INFO experiment_analysis.py:696 -- No `self.trials`. Drawing logdirs from checkpoint file. This may result in some information that is out of sync, as checkpointing is periodic.

# %%
df = analysis.results_df

# %%
# Out:
#              episode_reward_max  episode_reward_min  episode_reward_mean  \
# trial_id
# 6983a_00000                 0.0                 0.0                  0.0
# 6983a_00008                 NaN                 NaN                  NaN
# 6983a_00002                 NaN                 NaN                  NaN
# 6983a_00006                 NaN                 NaN                  NaN
# 6983a_00007                 NaN                 NaN                  NaN
# 6983a_00001                 NaN                 NaN                  NaN
# 6983a_00003                 NaN                 NaN                  NaN
# 6983a_00005                 NaN                 NaN                  NaN
# 6983a_00004                 NaN                 NaN                  NaN
#
#              episode_len_mean  episodes_this_iter  num_healthy_workers  \
# trial_id
# 6983a_00000              15.0               533.0                  0.0
# 6983a_00008               NaN                 NaN                  NaN
# 6983a_00002               NaN                 NaN                  NaN
# 6983a_00006               NaN                 NaN                  NaN
# 6983a_00007               NaN                 NaN                  NaN
# 6983a_00001               NaN                 NaN                  NaN
# 6983a_00003               NaN                 NaN                  NaN
# 6983a_00005               NaN                 NaN                  NaN
# 6983a_00004               NaN                 NaN                  NaN
#
#              timesteps_total  timesteps_this_iter  agent_timesteps_total  \
# trial_id
# 6983a_00000        1374624.0               7992.0              1374624.0
# 6983a_00008              NaN                  NaN                    NaN
# 6983a_00002              NaN                  NaN                    NaN
# 6983a_00006              NaN                  NaN                    NaN
# 6983a_00007              NaN                  NaN                    NaN
# 6983a_00001              NaN                  NaN                    NaN
# 6983a_00003              NaN                  NaN                    NaN
# 6983a_00005              NaN                  NaN                    NaN
# 6983a_00004              NaN                  NaN                    NaN
#
#               done  ...  \
# trial_id            ...
# 6983a_00000  False  ...
# 6983a_00008    NaN  ...
# 6983a_00002    NaN  ...
# 6983a_00006    NaN  ...
# 6983a_00007    NaN  ...
# 6983a_00001    NaN  ...
# 6983a_00003    NaN  ...
# 6983a_00005    NaN  ...
# 6983a_00004    NaN  ...
#
#              info.learner.default_policy.learner_stats.vf_explained_var  \
# trial_id
# 6983a_00000                                          -0.968421
# 6983a_00008                                                NaN
# 6983a_00002                                                NaN
# 6983a_00006                                                NaN
# 6983a_00007                                                NaN
# 6983a_00001                                                NaN
# 6983a_00003                                                NaN
# 6983a_00005                                                NaN
# 6983a_00004                                                NaN
#
#              info.learner.default_policy.learner_stats.kl  \
# trial_id
# 6983a_00000                                      0.005907
# 6983a_00008                                           NaN
# 6983a_00002                                           NaN
# 6983a_00006                                           NaN
# 6983a_00007                                           NaN
# 6983a_00001                                           NaN
# 6983a_00003                                           NaN
# 6983a_00005                                           NaN
# 6983a_00004                                           NaN
#
#             info.learner.default_policy.learner_stats.entropy  \
# trial_id
# 6983a_00000                                          0.495919
# 6983a_00008                                               NaN
# 6983a_00002                                               NaN
# 6983a_00006                                               NaN
# 6983a_00007                                               NaN
# 6983a_00001                                               NaN
# 6983a_00003                                               NaN
# 6983a_00005                                               NaN
# 6983a_00004                                               NaN
#
#             info.learner.default_policy.learner_stats.entropy_coeff  \
# trial_id
# 6983a_00000                                                0.0
# 6983a_00008                                                NaN
# 6983a_00002                                                NaN
# 6983a_00006                                                NaN
# 6983a_00007                                                NaN
# 6983a_00001                                                NaN
# 6983a_00003                                                NaN
# 6983a_00005                                                NaN
# 6983a_00004                                                NaN
#
#              config.evaluation_config.exploration_config.feature_net_config.fcnet_hiddens  \
# trial_id
# 6983a_00000                                                 []
# 6983a_00008                                                NaN
# 6983a_00002                                                NaN
# 6983a_00006                                                NaN
# 6983a_00007                                                NaN
# 6983a_00001                                                NaN
# 6983a_00003                                                NaN
# 6983a_00005                                                NaN
# 6983a_00004                                                NaN
#
#              config.evaluation_config.exploration_config.feature_net_config.fcnet_activation  \
# trial_id
# 6983a_00000                                               relu
# 6983a_00008                                                NaN
# 6983a_00002                                                NaN
# 6983a_00006                                                NaN
# 6983a_00007                                                NaN
# 6983a_00001                                                NaN
# 6983a_00003                                                NaN
# 6983a_00005                                                NaN
# 6983a_00004                                                NaN
#
#              config.evaluation_config.exploration_config.sub_exploration.type  \
# trial_id
# 6983a_00000                                 StochasticSampling
# 6983a_00008                                                NaN
# 6983a_00002                                                NaN
# 6983a_00006                                                NaN
# 6983a_00007                                                NaN
# 6983a_00001                                                NaN
# 6983a_00003                                                NaN
# 6983a_00005                                                NaN
# 6983a_00004                                                NaN
#
#              config.evaluation_config.tf_session_args.gpu_options.allow_growth  \
# trial_id
# 6983a_00000                                               True
# 6983a_00008                                                NaN
# 6983a_00002                                                NaN
# 6983a_00006                                                NaN
# 6983a_00007                                                NaN
# 6983a_00001                                                NaN
# 6983a_00003                                                NaN
# 6983a_00005                                                NaN
# 6983a_00004                                                NaN
#
#             config.evaluation_config.tf_session_args.device_count.CPU  \
# trial_id
# 6983a_00000                                                1.0
# 6983a_00008                                                NaN
# 6983a_00002                                                NaN
# 6983a_00006                                                NaN
# 6983a_00007                                                NaN
# 6983a_00001                                                NaN
# 6983a_00003                                                NaN
# 6983a_00005                                                NaN
# 6983a_00004                                                NaN
#
#             config.evaluation_config.multiagent.policies.default_policy
# trial_id
# 6983a_00000  [<class 'ray.rllib.policy.tf_policy_template.P...
# 6983a_00008                                                NaN
# 6983a_00002                                                NaN
# 6983a_00006                                                NaN
# 6983a_00007                                                NaN
# 6983a_00001                                                NaN
# 6983a_00003                                                NaN
# 6983a_00005                                                NaN
# 6983a_00004                                                NaN
#
# [9 rows x 366 columns]
